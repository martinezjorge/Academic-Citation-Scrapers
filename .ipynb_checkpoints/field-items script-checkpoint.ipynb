# %%
import pandas as pd
from selenium import webdriver
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as soup

# %%
college_data = pd.read_csv("department_urls.csv")
college_data
# Out:
#                    variable_name                            College  \
# 0                           acct  College of Business and Economics
# 1                    family_cons         Health & Human Development
# 2                        nursing         Health & Human Development
# 3               phys_therapy_adj         Health & Human Development
# 4                        finance  College of Business and Economics
# 5                      math_lect                   Science and Math
# 6                      math_lect                   Science and Math
# 7         asian_american_faculty              College of Humanities
# 8       asian_american_lecturers              College of Humanities
# 9      chicano_studies_lecturers              College of Humanities
# 10      modern_classical_faculty              College of Humanities
# 11     religious_studies_faculty              College of Humanities
# 12    religious_studies_emeritus              College of Humanities
# 13   religious_studies_lecturers              College of Humanities
# 14            africana_full_time       Social & Behavioral Sciences
# 15             africana_emeritus       Social & Behavioral Sciences
# 16            africana_lecturers       Social & Behavioral Sciences
# 17                   anthro_full       Social & Behavioral Sciences
# 18              anthro_lecturers       Social & Behavioral Sciences
# 19               anthro_emeritus       Social & Behavioral Sciences
# 20              criminal_justice       Social & Behavioral Sciences
# 21                 geo_full_time       Social & Behavioral Sciences
# 22                  geo_lecturer       Social & Behavioral Sciences
# 23                  geo_emeritus       Social & Behavioral Sciences
# 24                geo_affiliated       Social & Behavioral Sciences
# 25               history_faculty       Social & Behavioral Sciences
# 26             history_lecturers       Social & Behavioral Sciences
# 27              poli_sci_faculty       Social & Behavioral Sciences
# 28            poli_sci_lecturers       Social & Behavioral Sciences
# 29             poli_sci_emeritus       Social & Behavioral Sciences
# ..                           ...                                ...
# 79                 rec_tour_lect         Health & Human Development
# 80                       biology                   Science and Math
# 81                       biochem                   Science and Math
# 82                           geo                   Science and Math
# 83                      geo_lect                   Science and Math
# 84                        geo_em                   Science and Math
# 85       asian_american_emeritus              College of Humanities
# 86      linguistic_faculty_staff              College of Humanities
# 87            philosophy_faculty              College of Humanities
# 88          philosophy_lecturers              College of Humanities
# 89           philosophy_emeritus              College of Humanities
# 90       american_indian_faculty              College of Humanities
# 91                      comm_dis         Health & Human Development
# 92                 comm_dis_lect         Health & Human Development
# 93                  comm_diss_em         Health & Human Development
# 94                    health_sci         Health & Human Development
# 95               health_sci_lect         Health & Human Development
# 96                 heath_sci_adj         Health & Human Development
# 97                 health_sci_em         Health & Human Development
# 98       chicano_studies_faculty              College of Humanities
# 99          gender_women_faculty              College of Humanities
# 100       gender_women_lecturers              College of Humanities
# 101                        kines         Health & Human Development
# 102                   kines_lect         Health & Human Development
# 103                     kines_em         Health & Human Development
# 104                         blaw  College of Business and Economics
# 105                        blaw2  College of Business and Economics
# 106                        blaw3  College of Business and Economics
# 107     central_american_faculty              College of Humanities
# 108                        blaw4  College of Business and Economics
#
#      Department       classes         id  \
# 0           NaN           NaN  accordion
# 1           NaN           NaN  accordion
# 2           NaN           NaN  accordion
# 3           NaN           NaN  accordion
# 4           NaN           NaN  accordion
# 5           NaN           NaN  accordion
# 6           NaN           NaN  accordion
# 7           NaN           NaN  accordion
# 8           NaN           NaN  accordion
# 9           NaN           NaN  accordion
# 10          NaN           NaN  accordion
# 11          NaN           NaN  accordion
# 12          NaN           NaN  accordion
# 13          NaN           NaN  accordion
# 14          NaN           NaN  accordion
# 15          NaN           NaN  accordion
# 16          NaN           NaN  accordion
# 17          NaN           NaN  accordion
# 18          NaN           NaN  accordion
# 19          NaN           NaN  accordion
# 20          NaN           NaN  accordion
# 21          NaN           NaN  accordion
# 22          NaN           NaN  accordion
# 23          NaN           NaN  accordion
# 24          NaN           NaN  accordion
# 25          NaN           NaN  accordion
# 26          NaN           NaN  accordion
# 27          NaN           NaN  accordion
# 28          NaN           NaN  accordion
# 29          NaN           NaN  accordion
# ..          ...           ...        ...
# 79          NaN   field-items        NaN
# 80          NaN   field-items        NaN
# 81          NaN   field-items        NaN
# 82          NaN   field-items        NaN
# 83          NaN   field-items        NaN
# 84          NaN   field-items        NaN
# 85          NaN   field-items        NaN
# 86          NaN   field-items        NaN
# 87          NaN   field-items        NaN
# 88          NaN   field-items        NaN
# 89          NaN   field-items        NaN
# 90          NaN   field-items        NaN
# 91          NaN   field-items        NaN
# 92          NaN   field-items        NaN
# 93          NaN   field-items        NaN
# 94          NaN   field-items        NaN
# 95          NaN   field-items        NaN
# 96          NaN   field-items        NaN
# 97          NaN   field-items        NaN
# 98          NaN   field-items        NaN
# 99          NaN  view-content        NaN
# 100         NaN  view-content        NaN
# 101         NaN  view-content        NaN
# 102         NaN  view-content        NaN
# 103         NaN  view-content        NaN
# 104         NaN  view-content        NaN
# 105         NaN  view-content        NaN
# 106         NaN  view-content        NaN
# 107         NaN  view-content        NaN
# 108         NaN  view-content        NaN
#
#                                                    url
# 0    https://www.csun.edu/acctis/faculty-and-staff-...
# 1    https://www.csun.edu/health-human-development/...
# 2           https://www.csun.edu/nursing/faculty-staff
# 3    https://www.csun.edu/health-human-development/...
# 4       https://www.csun.edu/finance/faculty-directory
# 5    https://www.csun.edu/science-mathematics/mathe...
# 6    https://www.csun.edu/science-mathematics/mathe...
# 7    https://www.csun.edu/humanities/asian-american...
# 8    https://www.csun.edu/humanities/asian-american...
# 9    https://www.csun.edu/humanities/chicana-chican...
# 10   https://www.csun.edu/humanities/modern-classic...
# 11   https://www.csun.edu/humanities/religious-stud...
# 12   https://www.csun.edu/humanities/religious-stud...
# 13   https://www.csun.edu/humanities/religious-stud...
# 14   https://www.csun.edu/social-behavioral-science...
# 15   https://www.csun.edu/social-behavioral-science...
# 16   https://www.csun.edu/social-behavioral-science...
# 17   https://www.csun.edu/social-behavioral-science...
# 18   https://www.csun.edu/social-behavioral-science...
# 19   https://www.csun.edu/social-behavioral-science...
# 20   https://www.csun.edu/social-behavioral-science...
# 21   https://www.csun.edu/social-behavioral-science...
# 22   https://www.csun.edu/social-behavioral-science...
# 23   https://www.csun.edu/social-behavioral-science...
# 24   https://www.csun.edu/social-behavioral-science...
# 25   https://www.csun.edu/social-behavioral-science...
# 26   https://www.csun.edu/social-behavioral-science...
# 27   https://www.csun.edu/social-behavioral-science...
# 28   https://www.csun.edu/social-behavioral-science...
# 29   https://www.csun.edu/social-behavioral-science...
# ..                                                 ...
# 79   https://www.csun.edu/health-human-development/...
# 80   https://www.csun.edu/science-mathematics/biolo...
# 81   https://www.csun.edu/science-mathematics/chemi...
# 82   https://www.csun.edu/science-mathematics/geolo...
# 83   https://www.csun.edu/science-mathematics/geolo...
# 84   https://www.csun.edu/science-mathematics/geolo...
# 85   https://www.csun.edu/humanities/asian-american...
# 86   https://www.csun.edu/humanities/linguistics/fa...
# 87   https://www.csun.edu/humanities/philosophy/fac...
# 88   https://www.csun.edu/humanities/philosophy/lec...
# 89   https://www.csun.edu/humanities/philosophy/eme...
# 90   https://www.csun.edu/humanities/american-india...
# 91   https://www.csun.edu/health-human-development/...
# 92   https://www.csun.edu/health-human-development/...
# 93   https://www.csun.edu/health-human-development/...
# 94   https://www.csun.edu/health-human-development/...
# 95   https://www.csun.edu/health-human-development/...
# 96   https://www.csun.edu/health-human-development/...
# 97   https://www.csun.edu/health-human-development/...
# 98   https://www.csun.edu/humanities/chicana-chican...
# 99   https://www.csun.edu/humanities/gender-womens-...
# 100  https://www.csun.edu/humanities/gender-womens-...
# 101  https://www.csun.edu/health-human-development/...
# 102  https://www.csun.edu/health-human-development/...
# 103  https://www.csun.edu/health-human-development/...
# 104        https://www.csun.edu/blaw/faculty-directory
# 105  https://www.csun.edu/blaw/faculty-directory?fi...
# 106  https://www.csun.edu/blaw/faculty-directory?fi...
# 107  https://www.csun.edu/humanities/central-americ...
# 108  https://www.csun.edu/blaw/faculty-directory?fi...
#
# [109 rows x 6 columns]

# %%
field_items = college_data[college_data.classes == 'field-items']
field_items
# Out:
#                variable_name                         College  Department  \
# 74                  manu_sys  Engineering & Computer Science         NaN
# 75             manu_sys_lect  Engineering & Computer Science         NaN
# 76               manu_sys_em  Engineering & Computer Science         NaN
# 77           phys_therapy_pt      Health & Human Development         NaN
# 78                  rec_tour      Health & Human Development         NaN
# 79             rec_tour_lect      Health & Human Development         NaN
# 80                   biology                Science and Math         NaN
# 81                   biochem                Science and Math         NaN
# 82                       geo                Science and Math         NaN
# 83                  geo_lect                Science and Math         NaN
# 84                    geo_em                Science and Math         NaN
# 85   asian_american_emeritus           College of Humanities         NaN
# 86  linguistic_faculty_staff           College of Humanities         NaN
# 87        philosophy_faculty           College of Humanities         NaN
# 88      philosophy_lecturers           College of Humanities         NaN
# 89       philosophy_emeritus           College of Humanities         NaN
# 90   american_indian_faculty           College of Humanities         NaN
# 91                  comm_dis      Health & Human Development         NaN
# 92             comm_dis_lect      Health & Human Development         NaN
# 93              comm_diss_em      Health & Human Development         NaN
# 94                health_sci      Health & Human Development         NaN
# 95           health_sci_lect      Health & Human Development         NaN
# 96             heath_sci_adj      Health & Human Development         NaN
# 97             health_sci_em      Health & Human Development         NaN
# 98   chicano_studies_faculty           College of Humanities         NaN
#
#         classes   id                                                url
# 74  field-items  NaN  https://www.csun.edu/engineering-computer-scie...
# 75  field-items  NaN  https://www.csun.edu/engineering-computer-scie...
# 76  field-items  NaN  https://www.csun.edu/engineering-computer-scie...
# 77  field-items  NaN  https://www.csun.edu/health-human-development/...
# 78  field-items  NaN  https://www.csun.edu/health-human-development/...
# 79  field-items  NaN  https://www.csun.edu/health-human-development/...
# 80  field-items  NaN  https://www.csun.edu/science-mathematics/biolo...
# 81  field-items  NaN  https://www.csun.edu/science-mathematics/chemi...
# 82  field-items  NaN  https://www.csun.edu/science-mathematics/geolo...
# 83  field-items  NaN  https://www.csun.edu/science-mathematics/geolo...
# 84  field-items  NaN  https://www.csun.edu/science-mathematics/geolo...
# 85  field-items  NaN  https://www.csun.edu/humanities/asian-american...
# 86  field-items  NaN  https://www.csun.edu/humanities/linguistics/fa...
# 87  field-items  NaN  https://www.csun.edu/humanities/philosophy/fac...
# 88  field-items  NaN  https://www.csun.edu/humanities/philosophy/lec...
# 89  field-items  NaN  https://www.csun.edu/humanities/philosophy/eme...
# 90  field-items  NaN  https://www.csun.edu/humanities/american-india...
# 91  field-items  NaN  https://www.csun.edu/health-human-development/...
# 92  field-items  NaN  https://www.csun.edu/health-human-development/...
# 93  field-items  NaN  https://www.csun.edu/health-human-development/...
# 94  field-items  NaN  https://www.csun.edu/health-human-development/...
# 95  field-items  NaN  https://www.csun.edu/health-human-development/...
# 96  field-items  NaN  https://www.csun.edu/health-human-development/...
# 97  field-items  NaN  https://www.csun.edu/health-human-development/...
# 98  field-items  NaN  https://www.csun.edu/humanities/chicana-chican...

# %%
urls = field_items.url.tolist()

# %%
urls
# Out:
# ['https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/full-time-faculty',
#  'https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/lecturers',
#  'https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/emeritus-faculty',
#  'https://www.csun.edu/health-human-development/physical-therapy/Part-time-faculty',
#  'https://www.csun.edu/health-human-development/recreation-tourism-management/full-time-faculty',
#  'https://www.csun.edu/health-human-development/recreation-tourism-management/lecturers',
#  'https://www.csun.edu/science-mathematics/biology/faculty-staff',
#  'https://www.csun.edu/science-mathematics/chemistry-biochemistry/faculty-staff',
#  'https://www.csun.edu/science-mathematics/geology/full-time-faculty',
#  'https://www.csun.edu/science-mathematics/geology/lecturers',
#  'https://www.csun.edu/science-mathematics/geology/emeritus-faculty',
#  'https://www.csun.edu/humanities/asian-american-studies/emeritus-faculty',
#  'https://www.csun.edu/humanities/linguistics/faculty-staff',
#  'https://www.csun.edu/humanities/philosophy/faculty',
#  'https://www.csun.edu/humanities/philosophy/lecturers',
#  'https://www.csun.edu/humanities/philosophy/emeritus-faculty',
#  'https://www.csun.edu/humanities/american-indian-studies/faculty-staff',
#  'https://www.csun.edu/health-human-development/communication-disorders-sciences/full-time-faculty',
#  'https://www.csun.edu/health-human-development/communication-disorders-sciences/lecturers',
#  'https://www.csun.edu/health-human-development/communication-disorders-sciences/emeritus-faculty',
#  'https://www.csun.edu/health-human-development/health-sciences/full-time-faculty',
#  'https://www.csun.edu/health-human-development/health-sciences/lecturers',
#  'https://www.csun.edu/health-human-development/health-sciences/adjunct-faculty',
#  'https://www.csun.edu/health-human-development/health-sciences/retired-and-emeritus-faculty',
#  'https://www.csun.edu/humanities/chicana-chicano-studies/faculty']

# %%
len(urls)
# Out:
# 25

# %% [markdown]
# Fuguring out how slicing works

# %%
text = "asdf,asdf:asdf"
colon_pos = text.find(":")
comma_pos = text.find(",")
left_paren_pos = text.find("(")
text = text[:comma_pos]
text = text[:colon_pos]
text = text[:left_paren_pos]
print(text)
# Out:
# asd

# %%
url = urls[0]

# %%
def field_items_scraper(url):
    
    names = []
    driver = webdriver.Chrome()
    driver.get(url)
    
    field_soup = driver.find_element_by_class_name("field-items")
    
    if url == "https://www.csun.edu/science-mathematics/biology/faculty-staff":
        p_tags = driver.find_elements_by_xpath("html/body/div[3]/div/div/div[3]/article/div/div/div/p")
        names = [tag.text for tag in p_tags]
        while "" in names:
            names.remove("")
        clean_names = []
        for name in names:
            colon_pos = name.find(":")
            comma_pos = name.find(",")
            left_paren_pos = name.find("(")
            if colon_pos != -1:
                name = name[:colon_pos]
            if comma_pos != -1:
                name = name[:comma_pos]
            if left_paren_pos != -1:
                name = name[:left_paren_pos]
            clean_names.append(name)
        names = clean_names
        names = names[2:101]
    
    elif url == 'https://www.csun.edu/humanities/american-indian-studies/faculty-staff' :
        raw_names = driver.find_elements_by_xpath('html/body/div[3]/div/div/div[3]/article/div/div/div/h2')
        raw_names = [name.text for name in raw_names]
        names = []
        for name in raw_names:
            comma_pos = name.find(",")
            names.append(name[:comma_pos])


    # this one is still tough
    elif url == 'https://www.csun.edu/health-human-development/health-sciences/lecturers':
        raw_names = driver.find_elements_by_xpath("html/body/div[3]/div[2]/div/div[3]/article/div/div/div/p")
        raw_names2 = driver.find_elements_by_xpath("html/body/div[3]/div[2]/div/div[3]/article/div/div/div/blockquote/p[2]")
        
        raw_names = [web_obj.find_element_by_tag_name("a") for web_obj in raw_names]
        names = [name.text for name in raw_names]
        
        #raw_names2 = [web_obj.find_element_by_tag_name("p") for web_obj in raw_names2]
        names2 = [name.text for name in raw_names2]
        
        names += names2
        
        #raw_names = [name.get_attribute("innerHTML") for name in raw_names]
        #for name in raw_names:
        #    print(name)
        
        
    # if it has a table
    elif field_soup.find_elements_by_tag_name("tbody"):
        print("table script ran")
        field_soup = field_soup.find_element_by_tag_name("tbody")
        if field_soup.find_elements_by_xpath("//tr/th"):
            print("a")
            web_objects = field_soup.find_elements_by_xpath("//tr/th")
            names = [web_object.text for web_object in web_objects]
        elif field_soup.find_elements_by_xpath("//tr/td/h3/img"):
            print("b")
            web_objects = field_soup.find_elements_by_xpath("//h3/img")
            names = [web_object.get_attribute("alt") for web_object in web_objects]
        elif field_soup.find_elements_by_xpath("//tr/td/h2"):
            print("c")
            web_objects = field_soup.find_elements_by_xpath("//tr/td/h2")
            names = [web_object.text for web_object in web_objects]
        elif field_soup.find_elements_by_xpath('//tr/td/ul/li[1]/h2'):
            print("d")
            web_objects = field_soup.find_elements_by_xpath('//tr/td/ul/li[1]/h2')
            names = [web_object.text for web_object in web_objects]
        else:
            print("e")
            field_soup = field_soup.find_elements_by_tag_name("tr")
            web_objects = []
            for row in field_soup:
                web_objects.append(row.find_element_by_tag_name("td"))
            field_soup = web_objects
            fields = [field for field in field_soup]
            names = [field.text for field in fields]
        print(names)
    
    # this really needs to be cleaned up
    elif field_soup.find_elements_by_xpath("//div/blockquote/p/strong"):
        print("blockquote script 1 ran")
        first_name_objects = field_soup.find_elements_by_xpath("//p/strong/a")
        last_name_objects = field_soup.find_elements_by_xpath("//div/blockquote/p/a/strong")
        name_objects = field_soup.find_elements_by_xpath("//div/p/a/strong")
        first_names = [web_object.text for web_object in first_name_objects]
        last_names = [web_object.text for web_object in last_name_objects]
        more_names = [web_object.text for web_object in name_objects]

        print(first_names)
        print(last_names)
        print(more_names)
        
        # still need to combine all these into names
        
    elif field_soup.find_elements_by_xpath("//div/blockquote/p/a"):
        print("blockquote script 2 ran")
        name_objects = field_soup.find_elements_by_xpath("//div/blockquote/p/a")
        names = [web_object.text for web_object in name_objects]
        
    elif field_soup.find_elements_by_xpath("//div/blockquote/p"):
        print("blockquote script 3 ran")
        name_objects = field_soup.find_elements_by_xpath("//div/blockquote/p/a")
        names = [web_object.text for web_object in name_objects]
        
    # have to make this a bit less general
    elif field_soup.find_elements_by_tag_name("li"):
        print("list script ran")
        field_soup = field_soup.find_elements_by_tag_name("li")
        fields = [field for field in field_soup]
        names = [field.text for field in fields]
        print(names)
        
    # too general
    elif field_soup.find_elements_by_xpath("//div/h2"):
        print("h2 script outside table ran")
        web_objects = field_soup.find_elements_by_xpath("//div/h2")
        names = [web_object.text for web_object in web_objects]
        names = names[4]
        
    elif field_soup.find_elements_by_xpath("//a"):
        print("a script ran")
        a_soup = field_soup.find_elements_by_tag_name("//a")
        fields = [field for field in a_soup]
        names = [field.text for field in fields]
    
    else:
        print("Didn't Scrape")
    
    driver.close()
    
    return names

# %%
names = field_items_scraper(urls[21])

# %%
counter = 0
for name in names:
    print(counter, " " , name)
    counter += 1
# Out:
# 0   Michael Bruse
# 1   Marsha Chan
# 2   Lisa Chaudhari
# 3     Crystal Adams
#   Lecturer
#   Email: crystal.adams@csun.edu
#   Office: Laurel Hall
#   Program: Public Health
#   Click Profile for More Details & Office Hours
#
#
#   Yazeed Alhiyari
#   Lecturer
#   Email: yazeed.alhiyari@csun.edu
#   Office: Laurel Hall
#   Program: Health Administration & Public Health
#   Click Profile for More Details & Office Hours
# 4     Francesco Chiappelli
#   Lecturer
#   Email: francesco.chiappelli@csun.edu
#   Office: Laurel Hall
#   Program: Health Administration & Public Health
#   Click Profile for More Details & Office Hours
#
#
#   Damon Cianci
#   Lecturer
#   Email: damon.cianci.19@csun.edu
#   Office: Laurel Hall
#   Program: Health Administration
#   Click Profile for More Details & Office Hours
#
#
#
#   Danielle Co
#   Teaching Assistant
#   Email: danielleerika.co.523@my.csun.edu
#   Office: Laurel Hall
#   Program: Public Health
#
#
#   Susan Cohen
#   Lecturer
#   Email: susan.cohen@csun.edu
#   Office: JD-2515
#   Program: Health Administration & Public Health
#   Click Profile for More Details & Office Hours
# 5     Iisha Coleman
#   Lecturer
#   Email: iisha.coleman@csun.edu
#   Office: JD-1509
#   Program: Radiologic Sciences
#   Click Profile for More Details & Office Hours
#
#
#   Robin Edmonds
#   Lecturer
#   Email:  robin.d.edmonds@csun.edu
#   Office: Laurel Hall
#   Program: Public Health
#   Click Profile for More Details & Office Hours

# %%
counter = 0
for url in urls:
    print(counter,":",url)
    counter += 1
# Out:
# 0 : https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/full-time-faculty
# 1 : https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/lecturers
# 2 : https://www.csun.edu/engineering-computer-science/manufacturing-systems-engineering-management/emeritus-faculty
# 3 : https://www.csun.edu/health-human-development/physical-therapy/Part-time-faculty
# 4 : https://www.csun.edu/health-human-development/recreation-tourism-management/full-time-faculty
# 5 : https://www.csun.edu/health-human-development/recreation-tourism-management/lecturers
# 6 : https://www.csun.edu/science-mathematics/biology/faculty-staff
# 7 : https://www.csun.edu/science-mathematics/chemistry-biochemistry/faculty-staff
# 8 : https://www.csun.edu/science-mathematics/geology/full-time-faculty
# 9 : https://www.csun.edu/science-mathematics/geology/lecturers
# 10 : https://www.csun.edu/science-mathematics/geology/emeritus-faculty
# 11 : https://www.csun.edu/humanities/asian-american-studies/emeritus-faculty
# 12 : https://www.csun.edu/humanities/linguistics/faculty-staff
# 13 : https://www.csun.edu/humanities/philosophy/faculty
# 14 : https://www.csun.edu/humanities/philosophy/lecturers
# 15 : https://www.csun.edu/humanities/philosophy/emeritus-faculty
# 16 : https://www.csun.edu/humanities/american-indian-studies/faculty-staff
# 17 : https://www.csun.edu/health-human-development/communication-disorders-sciences/full-time-faculty
# 18 : https://www.csun.edu/health-human-development/communication-disorders-sciences/lecturers
# 19 : https://www.csun.edu/health-human-development/communication-disorders-sciences/emeritus-faculty
# 20 : https://www.csun.edu/health-human-development/health-sciences/full-time-faculty
# 21 : https://www.csun.edu/health-human-development/health-sciences/lecturers
# 22 : https://www.csun.edu/health-human-development/health-sciences/adjunct-faculty
# 23 : https://www.csun.edu/health-human-development/health-sciences/retired-and-emeritus-faculty
# 24 : https://www.csun.edu/humanities/chicana-chicano-studies/faculty

# %%
See what can be done about                                table script
21 missed a lot of professors                             blockquote 2
22 completely missed                                      blockquote 1

# %%
counter = 0
all_names = []
for url in urls:
    print("URL ", counter)
    all_names.append(field_items_scraper(url))
    counter += 1
# Out:
# URL  0
# list script ran
# ['Professor Behzad Bavarian, Department Chair ', 'Professor Kang Chang (FERP) ', 'Professor Robert D. Conner, ', 'Professor Ileana Costea (FERP)', 'Professor Shereazad Jimmy Gandhi, Assessment Coordinator', 'Professor Bingbing Li', 'Professor Mark Rajai', 'Professor Ahmad Sarfaraz (Academic Advisor) ', 'Professor Maryam Tabibzadeh', 'Professor Durul Ulutan']
# URL  1
# list script ran
# ['Professor Khashayar Behdinan', 'Professor Guido Canzona', 'Professor Luis Echeverria', 'Professor Gus H. Elias', 'Professor Hamid Gholami', 'Professor Jay Hamade', 'Professor Jaleh Jahangiri', 'Professor Fereshteh Lavassani', 'Professor Anthony Magee', 'Professor Chima Ojukwu', 'Professor Lisa Reiner', 'Professor Babak Samimi', 'Professor Hans Shin', 'Professor Adrian Sita', 'Professor Salpy R. Tovar', 'Professor Shahriar Vazan', 'Professor Scott Wainess']
# URL  2
# list script ran
# ['Professor Bonita Campbell', 'Professor Jon Shively', 'Professor Gerald Davis', 'Professor Melvin Lifson', 'Professor Arnold Roe']
# URL  3
# table script ran
# e
# ['Bacic, Carole, BFA', 'Barba, Richard, PT, DPT, MPT, GCS, BS', 'Burke-Doe, Annie, PhD, DPT, MPT, BS', 'Burton, Thomas, PT', 'Carrle, Raylean, MPT, BA', 'Chang, Julia, PhD', 'Clamor, Charmaine, MPT, BS', 'Donnelly, Judd, DPT, OCS, MPT, BFA', 'Druz, Viktoria, PT, MPT, BS', 'Ellis, Anne, DPT, BA', 'Ferreira, Isabel, DPT, BS', 'Hamilton, Justin, PT, DPT, OCS, MPT', 'Hawson, Suzanne, PT, DPT, OCS, MPT, BS', 'Huntsman-Lannom, Debra, PT', 'Jimeno, Francisco, MPT, MS', 'Kamrava, Shandiz, DPT, BA', 'Katz, Richard, DPT, MA', 'Linares, Ernie, PT, DPT, FAAOMPT, OCS, BA', 'Macnaughton, Lorraine, PT, BS', 'Malaspina, Stephanie, PT, DPT, BS', 'Monroy, Edwin, PT, DPT, CLT, CWS', 'Murakami, Mae, DPT, BS', 'Panama, Gabriel, DPT, MPT, BS', 'Sapienza, Allison, DPT, BS', 'Sinn, Jared, DPT, BS', 'Stewart, Myra, DPT, BFA', 'Tyler, Kristy, MPT, BS', 'White, Chris, DPT, EMT-B, MSPT, OCS, BS', 'Xiao, Danny, DPT, BS', 'Zandi, Yvonne, DPT, MPT, BS']
# URL  4
# table script ran
# e
# ['Dr. Mechelle Best, Dept. Chair', 'Dr. Jose Gonzalez', 'Dr. Joong-won Lee, ', 'Dr. Nathan Martin', 'Dr. Dianne Philibosian', 'Dr. HeeKyung (Erika) Sung', 'Dr. Veda Ward', 'Dr. Alan Wright', 'Dr. Hui (Jimmy) Xie']
# URL  5
# table script ran
# e
# ['Applen, Brittany', 'Castillo, Francisca', 'Chesley, Erika', 'Despain, Joel', 'Garrovillas, Erin', 'Lavin, Kaila', 'Luo, Lawrence', 'Newton, Delfina', 'Sachs, Robin', 'Schmidt, Jason', 'Schuster, Paulette', 'Shade, Babette', 'Szczespanski, Tim', 'Van Arsdale, John', 'Vincent, Leanne', 'Whitesides, Chris ', 'Wilsey, Kassandra', 'Yost, Wendy']
# URL  6
# URL  7
# table script ran
# e
# ['Edward J. Carroll', 'Karin Hassenrueck ', 'Douglas Holub', 'Kayla Kaiser', 'Kamatchi Lakshminarayanan', 'Robert A. Montgomery']
# URL  8
# table script ran
# c
# ['Cecil, Robinson', 'Cotton, Jennifer', "d'Alessio, Matthew", 'Evans, Eileen', 'Ganguli, Priya', 'Hauswirth, Scott', 'Heermance, Richard', 'Lozos, Julian', 'Marsaglia, Kathleen', 'Miranda, Elena', 'Schwartz, Joshua', 'Tabidian, M. Ali', 'Weeraratne, Dayanthie', 'Yule, Doug']
# URL  9
# table script ran
# c
# ['Fleck, Jenna', 'Huerta, Brittany', 'McBurnett, Paul', 'Miller, Kimberly', 'Pavia, Jenni', 'Savage, Karen']
# URL  10
# table script ran
# c
# ['Adams, Herbert G.', 'Collins, Lorence G.', 'Dunne, George C.', 'Pedone, Vicki', 'Simila, Gerry', 'Sloan, Jon', 'Squires, Richard']
# URL  11
# h2 script outside table ran
# ['College of\nHumanities', '', '', '', 'Enrique de la Cruz, Ph.D.', 'Faculty & Staff']
# URL  12
# table script ran
# a
# ['Name', 'Email', 'Areas of Specialization', 'Anne Crawford\nLecturer in Linguistics', 'Joseph Galasso\nLecturer in Linguistics', 'Shadi Ganjavi\nLecturer in Linguistics', 'John Gides\nLecturer in Linguistics', 'Anna Dina L. Joaquin\nDept. of Linguistics/TESL', 'Bessie Karras-Lazaris\nIntensive English Program', 'Stephanie Hyeri Kim\nDept. of Linguistics/TESL', 'Sharon Klein\nDept. of English & Dept. of Linguistics/TESL', 'Rebecca Litke\nDept. of Communication Studies', 'Kenneth V. Luna\nDept. of Linguistics/TESL', 'Terrie Mathis\nLecturer in Linguistics', 'David J. Medeiros\nDept. of Linguistics/TESL', 'Laura Ruth-Hirrel\nDept. of Linguistics/TESL', 'Ana Sánchez Muñoz\nDept. of Chicana/o Studies', 'Tineke Scholten\nLecturer in Linguistics', 'Wendy Snyder\nLecturer in Linguistics', 'Hyung-Jo Yoon\nDept. of Linguistics/TESL']
# URL  13
# table script ran
# d
# ['Tim Black, Chair\nProfessor', 'Abel Franco\nAssociate Professor', 'Robert Gressis\nAssociate Professor', 'Jacob Hale\nProfessor', 'Sarah Hansen\nAssistant Professor', 'Kristina Meshelski, Associate Chair\nAssociate Professor', 'Robin M. Muller\nAssistant Professor', 'Bonnie Paller\nProfessor', 'Adam Swenson\nProfessor', 'Weimin Sun\nProfessor', 'Gregory Velazco y Trianosky\nProfessor', 'Takashi Yagisawa\nProfessor', 'Julie Yoo\nAssociate Professor']
# URL  14
# table script ran
# d
# ['John Birmingham', 'Dennis Brandon', 'Valerie Giovanini', 'Mitchell Herschbach', 'Justin Kitchen', 'Daniel Kwon', 'Leemon McHenry', 'Markar Melkonian', 'Christopher Pallotti', 'Mark Pressman', 'Li Schroeder', 'Mojgan Taheri', 'Birgit Tregenza']
# URL  15
# table script ran
# d
# ['Charles Crittenden', 'James Kellenberger', 'Ronald McIntyre', 'Richard Rodewald']
# URL  16
# list script ran
# ['B.A., University of Oklahoma, 1987', 'M.A., University of California, Riverside, 1993', 'Ph.D., University of California, Riverside, 2000', 'M.A., Massey University (NZ), 2010', 'Ph.D., University of Aukland (NZ), 2016', 'B.A., CSUN, 2015', 'M.A., UCLA, 2017']
# URL  17
# table script ran
# e
# ['Biel, Michael E', 'Hall, Edward P', 'Jackson, Catherine A', 'Jin, Su-Hyun', 'Kochis-Jennings, Karen A', 'Seymour, Patricia J', 'Sinclair, J. Stephen', 'Strike-Roussos, Christine', 'Weber, Elizabeth G', 'Yu, Vickie']
# URL  18
# table script ran
# e
# ['Anvari, Padideh', 'Cartwright, Laurie M', 'Cathcart, Sarah E', 'Fenig, Marshall J', 'Hernandez, Amalia', 'Hochman, Ruth', 'Karahalios, Delia', 'La Rue, Linda', 'Lew, Gail W', 'Malan, John', 'Miller, Amanda B', 'Parmenter, Wendy I', 'Schmidt, Deandra', 'Spayd, Karen A']
# URL  19
# table script ran
# e
# ['Trost-Cardamone, Judith E']
# URL  20
# blockquote script 1 ran
# ['Doris', 'Frankline "Frankie" Augustin', 'Stephanie Benjamin', 'Kacie Blackman', 'Sloane Burke-Winkelman', 'Lawrence Chu', 'Stephan (Kyusuk) Chung', 'Stephen Duarte', 'Vicki Ebin', 'Merav Efrat', 'Bobbie (Roberta) Emetu', 'Myriam Forster', 'Jennifer Little', 'Gretta Madjzoob', 'Brian Malec', 'Carrie Pullen']
# [' Abrishami', 'Patty (Patchareeya) Kwan']
# ['Kaitlin Bahr', 'Grishma Bhavsar', 'Salvador Esparza', 'Bethany Rainisch', 'Louis Rubino', 'Carmen Saunders-Russell', 'Mirna Sawyer', 'Anita Slechta', 'Suzanne Spear', 'Claudia Toledo-Corral', 'Jenny Yi', 'Kathleen Young']
# URL  21
# blockquote script 2 ran
# URL  22
# blockquote script 1 ran
# []
# []
# []
# URL  23
# table script ran
# e
# ['Ronald Fischbach', 'Deborah Forman']
# URL  24
# table script ran
# d
# ['Christina Ayala-Alcantar\nProfessor', 'Yreina Cervantez\nProfessor', 'Martha Escobar\nAssociate Professor', 'Alicia Ivonne Estrada\nProfessor', 'Xóchitl M. Flores-Marcial\nAssistant Professor', 'Melisa C. Galván\nAssistant Professor', 'Peter J. García\nProfessor', 'Ramón García\nProfessor', 'Rosemary Gonzalez\nAssociate Professor', 'Gabriel Gutiérrez\nProfessor and Department Chair', 'Fermin Herrera\nProfessor', 'Maria Isabel Herrera\nProfessor', 'Marta Lopez-Garza\nProfessor', 'Lara Medina\nProfessor', 'Theresa Montaño\nProfessor', 'Renee Moreno\nProfessor', 'Roberta Orona-Cordova\nProfessor', 'Mary Pardo\nProfessor', 'Rosa RiVera-Furumoto\nProfessor', 'David Rodriguez\nProfessor', 'Stevie Ruiz\nAssistant Professor', 'Ana Sánchez-Muñoz\nProfessor', 'Denise Sandoval\nProfessor', 'Francisco Tamayo\nAssistant Professor', 'Yarma Velázquez-Vargas\nAssociate Professor']

# %%
#all_names
