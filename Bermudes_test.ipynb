# %%
import pandas as pd

# %%
pd.read_csv("bermudes.csv", sep="|")
# Out:
#             faculty                                              title  \
# 0    David Bermudes  Epiphytic bromeliads as air quality monitors i...
# 1    David Bermudes          Symbiosis inferred from the fossil record
# 2    David Bermudes                    Tumour therapy using Salmonella
# 3    David Bermudes  VNP20009, a genetically modified Salmonella ty...
# 4    David Bermudes  Molecular characterization of the dense granul...
# 5    David Bermudes  Accumulation of single-stranded DNA in Escheri...
# 6    David Bermudes  The role of parasites in generating evolutiona...
# 7    David Bermudes  In vitro antagonism of bioluminescent fungi by...
# 8    David Bermudes  Tumor-targeted Salmonella as a novel anticance...
# 9    David Bermudes  Lipid A mutant Salmonella with suppressed viru...
# 10   David Bermudes               Bacteria as tumour-targeting vectors
# 11   David Bermudes  Biodistribution and Genetic Stability of the N...
# ...
