# %%
import pandas as pd
import numpy as np

# %%
new_scholar_works = pd.read_csv('new_scholar_works.csv')

# %%
new_scholar_works.sample(25)
# Out:
#                      authors  \
# 10081      Stout, Jeffrey R.
# 4877           Huynh, Steven
# 2119            Conlee, R.K.
# 205         Almassian, Bijan
# 2007        Cloninger, Cheri
# 585      Balmaceda, Laura A.
# 2131          Conroy, Lauren
# 11874             Yule, Doug
# 901    Bernthal, Nicholas M.
# 1557          Case, David A.
# 6594          Lohmann, Jan U
# 847              Bentley, S.
# 2965      Ellner, Carolyn L.
# 2753            Du, Shi-Xuan
# 1501        Carpenter, R. C.
# 10055      Stevens Stern, D.
# 10720           Udekwu, Klas
# 2682      Dorcas, Michael E.
# 9926         Souvaine, Diane
# 6155                Lauss, B
# 8394      Plummer, Thomas W.
# 3544                 Gao, Li
# 994        Block, Matthew S.
# 9816             Smalley, B.
# 617         Barbar, Mary Lee
#
#                                            collaborators  \
# 10081  Aragon, Alan A.; Schoenfeld, Brad J.; Wildman,...
# 4877   Pascoe, Ben; Méric, Guillaume; Yahara, Koji; W...
# 2119   Nelson, Arnold; Arnall, D.A.; Loy, S.F.; Silve...
# 205    Lee, King C.; Zheng, Li-Mou; Luo, Xiang; Clair...
# 2007   Cloninger, Cheri; Felton, Marilyn; Paul, Bonni...
# 585    Muñoz-Jaramillo, Andrés; Senkpeil, Ryan R.; Wi...
# 2131                         Conroy, Lauren; Gray, David
# 11874  Meigs, Andrew; Yule, Doug; Blythe, Ann; Burban...
# 901    Bernthal, Nicholas M.; Schwartz, Adam J.; Oake...
# 1557        Joung, In Suk; Luchko, Tyler; Case, David A.
# 6594   Maier, Annette T; Stehling-Sun, Sandra; Wollma...
# 847    Christian, Damian J.; Gibson, N.P.; Simpson, E...
# 2965   Oppenheimer, Steven B., 1944-; Ellner, Carolyn...
# 2753                Gao, Li; Du, Shi-Xuan; Gao, Hong-Jun
# 1501   Comeau, S.; Tambutté, E.; Carpenter, R. C.; Ed...
# 10055  Morales, F. Y.; Werner, M. W.; Padgett, D.; Fa...
# 10720  Simpson, Madeline; Hjelmqvist, Daisy; López-Al...
# 2682   Böhm, Monika; Collen, Ben; Baillie, Jonathan E...
# 9926   Barequet, Gill; Cannon, Sarah; Fox-Epstein, El...
# 6155   Ishiwatari, T; Beer, G; Bragadireanu, A.M; Car...
# 8394   Ferraro, Joseph V.; Plummer, Thomas W.; Pobine...
# 3544                Gao, Li; Du, Shi-Xuan; Gao, Hong-Jun
# 994    Jiang, Hong-Chen; Block, Matthew S.; Mishmash,...
# 9816   Christian, D. J.; Gibson, N. P.; Simpson, E. K...
# 617    Oppenheimer, Steven B., 1944-; Potter, Richard...
#
#                                                   titles dates  \
# 10081  International Society Of Sports Nutrition Posi...  2017
# 4877   Local Genes For Local Bacteria: Evidence Of Al...  2017
# 2119   Consequences of Combining Strength and Enduran...  1990
# 205    Comparative evaluation of the acute toxic effe...  2000
# 2007   Control of pH during plasmid preparation by al...  2008
# 585    Small-Scale And Global Dynamos And The Area An...  2015
# 2131   Male Armaments And Reproductive Behavior In "N...  2015
# 11874  Implications Of Distributed Crustal Deformatio...  2003
# 901    How Long Do Endoprosthetic Reconstructions For...  2010
# 1557   Simple electrolyte solutions: Comparison of DR...  2013
# 6594   Dual roles of the bZIP transcription factor PE...  2009
# 847    WASP-10b: a 3MJ, gas-giant planet transiting a...  2009
# 2965       How do you get a Nobelist into your classroom  1987
# 2753   Anchoring of a single molecular rotor and its ...  2010
# 1501   Coral Calcifying Fluid Ph Is Modulated By Seaw...  2017
# 10055  Stellar Objects with Infrared Excess in the\te...  2005
# 10720  Anti-Peroxyl Radical Quality And Antibacterial...  2013
# 2682     The conservation status of the world’s reptiles  2013
# 9926              Diffuse Reflections in Simple Polygons  2013
# 6155   Kaonic nitrogen X-ray transition yields in a g...  2004
# 8394   Earliest archaeological evidence of persistent...  2013
# 3544   Anchoring of a single molecular rotor and its ...  2010
# 994    Non-Fermi-Liquid D-Wave Metal Phase Of Strongl...  2012
# 9816   Wasp-10B: A 3M J , Gas-Giant Planet Transiting...  2009
# 617    Alteration of Sea Urchin Embryo Cell Surface P...  1973
#
#                                                abstracts
# 10081  Position Statement: The International Society ...
# 4877   The genetic structure of bacterial populations...
# 2119   A common belief among many clinicians and trai...
# 205    The objective of these studies was to perform ...
# 2007   Alkaline lysis of Escherichia coli is usually ...
# 585    In this work, we take advantage of 11 differen...
# 2131   Males of many species possess striking weaponr...
# 11874  Spatial and temporal patterns of exhumation ar...
# 901    Background As the life expectancy of patients ...
# 1557   Using the dielectrically consistent reference ...
# 6594   Flowers develop from floral meristems, which h...
# 847    We report the discovery ofWASP-10b, a new tran...
# 2965   We have compiled a partial list of Nobel laure...
# 2753   Functionalizing of single molecules on surface...
# 1501   Reef coral calcification depends on regulation...
# 10055  We have identified two new debris disk candida...
# 10720  The anti-peroxyl radical quality of two aqueou...
# 2682   Effective and targeted conservation action req...
# 9926   We prove a conjecture of Aanjaneya, Bishnu, an...
# 6155   The first measurement of the yields of three k...
# 8394   The emergence of lithic technology by ∼2.6 mil...
# 3544   Functionalizing of single molecules on surface...
# 994    Developing a theoretical framework for conduct...
# 9816   We report the discovery of WASP-10b, a new tra...
# 617    Sea urchin embryos incubated in sea water cont...

# %%
authors = new_scholar_works['authors'].tolist()

# %%
len(authors)
# Out:
# 12199

# %% [markdown]
# ### full_name_parser function
#
# This function will clean up full names found in documents, attempting to seperate their full names into first, middle, and last into a dictionary.
#
# The only draw back is asian names who seem say their last names first followed by the first names.
#
# It mostly works okay. It doesn't always split the first and middle names correctly but it seems to always seperate out the last name which for this situation works great because we are trying to do a fuzzy match on the last names with other names that we have in other files.

# %%
def full_name_parser(full_name):

    d = {
        'first' : '',
        'middle' : '',
        'last' : ''
    }
    
    # check by comma space
    if ', ' in full_name:
        split_by_comma_space = full_name.split(', ')
        d['last'] = split_by_comma_space[0]
        split_by_space = split_by_comma_space[1].split(' ')
        if len(split_by_space) == 1:
            d['first'] = split_by_space[0]
        elif len(split_by_space) == 2:
            d['first'] = split_by_space[0]
            d['middle'] = split_by_space[1]
            
    elif len(full_name.split()) == 1:
        
        d['last'] = full_name.strip()
        
    elif len(full_name.split()) == 2:
        
        split_by_space = full_name.split()
        d['first'] = split_by_space[0]
        d['last'] = split_by_space[1]
        
    elif len(full_name.split()) == 3:
        
        split_by_space = full_name.split()
        d['first'] = split_by_space[0]
        d['middle'] = split_by_space[1]
        d['last'] = split_by_space[2]
        
    elif len(full_name.split()) == 4:
        split_by_space = full_name.split()
        d['first'] = split_by_space[0]
        d['middle'] = split_by_space[1]
        d['last'] = split_by_space[2] + " " + split_by_space[3]
        
    return d

# %% [markdown]
# Here I actually use the function to build a list of dictionaries.

# %%
full_names=[]
for i, full_name in enumerate(authors):
    full_names.append(full_name_parser(full_name))

# %% [markdown]
# Now I'll create parallel lists out of the dictionaries

# %%
first = []
middle = []
last = []
for d in full_names:
    first.append(d['first'])
    middle.append(d['middle'])
    last.append(d['last'])

# %% [markdown]
# I'll add the lists as columns to new_scholar_works

# %%
new_scholar_works['first_names'] = first
new_scholar_works['middle_names'] = middle
new_scholar_works['last_names'] = last

# %%
new_scholar_works.head()
# Out:
#             authors                                      collaborators  \
# 0     A'Hearn, M.F.  Meech, K.J.; A'Hearn, M.F.; Adams, J.A.; Bacci...
# 1      A.C. Asperti  A.C. Asperti; H.P. De Castro; M.H. Noronha; As...
# 2        Aballe, L.  Clarkson, J. D.; Fina, I.; Liu, Z. Q.; Lee, Y....
# 3     Abasi, Lannah  Snoussi, Mehdi; Talledo, Paul; Del Rosario, Na...
# 4  Abdala, Caroline            Abdala, Caroline; Visser-Dumont, Leslie
#
#                                               titles dates  \
# 0  EPOXI: comet 103P/Hartley 2 observations from ...  2011
# 1  Compact homogeneous Einstein manifolds in codi...  1996
# 2  Hidden Magnetic States Emergent Under Electric...  2017
# 3  Population Dynamics of Antimicrobial Peptide's...  2017
# 4  Distortion Product Otoacoustic Emissions: A To...  2001
#
#                                            abstracts first_names middle_names  \
# 0  Earth- and space-based observations provide sy...        M.F.
# 1  In this paper we study compact Riemannian homo...        A.C.
# 2  The ability to control a magnetic phase with a...          L.
# 3  Antimicrobial peptides (AMPs) are broad spectr...      Lannah
# 4  Distortion product otoacoustic emissions (DPOA...    Caroline
#
#   last_names
# 0    A'Hearn
# 1    Asperti
# 2     Aballe
# 3      Abasi
# 4     Abdala

# %% [markdown]
# Now I can get just the last names so I can try to fuzzy match them to the names that we already have in other files.
#
# I think I want to get the names that we already matched all_faculty and sandbox scraper so I can get the email that's associated with them.
#
# I might want to enumarate them. I just want a name that I can use to join with to attach emails to them.

# %% [markdown]
# What I can also do is attempt to build the names in a more proper format.
#
# Find all the unique names.
#
# Then try to do fuzzy matching on that.

# %%
first = new_scholar_works.first_names.tolist()
middle = new_scholar_works.middle_names.tolist()
last = new_scholar_works.last_names.tolist()

# %%
full_names = []
for i in range(len(first)):
    full_name = ""
    full_name += first[i]
    if middle[i] != '':
        full_name += ' ' + middle[i]
    full_name += ' ' + last[i]
    full_names.append(full_name)

# %%
full_names[:10]
# Out:
# ["M.F. A'Hearn",
#  'A.C. Asperti',
#  'L. Aballe',
#  'Lannah Abasi',
#  'Caroline Abdala',
#  ' Abdeljawad',
#  'Ashraf Abdelkerim',
#  'J. Abdulla',
#  'T. Abe',
#  'T. Abe']

# %%
Kerry satamaro female
chris kechityan
ryan holbreg enterprenuarial
tim timmen icore the art of the pitch guy kawazaki 302010
