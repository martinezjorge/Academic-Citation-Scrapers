# %%
import pandas as pd
import numpy as np

# %%
catalog_content = pd.read_csv("google_scholar_citations.csv",sep="|")

# %%
catalog_content
# Out:
#                faculty  citation  \
# 0           Kyle Dewey       NaN
# 1           Kyle Dewey       NaN
# 2           Kyle Dewey       NaN
# 3           Kyle Dewey       NaN
# 4           Kyle Dewey       NaN
# 5           Kyle Dewey       NaN
# 6           Kyle Dewey       NaN
# 7    Steven Fitzgerald       NaN
# 8    Steven Fitzgerald       NaN
# 9    Steven Fitzgerald       NaN
# 10   Steven Fitzgerald       NaN
# 11   Steven Fitzgerald       NaN
# 12      Ani Nahapetian       NaN
# 13      Ani Nahapetian       NaN
# 14      Ani Nahapetian       NaN
# 15      Ani Nahapetian       NaN
# 16      Ani Nahapetian       NaN
# 17      Ani Nahapetian       NaN
# 18      Ani Nahapetian       NaN
# 19      Ani Nahapetian       NaN
# 20      Ani Nahapetian       NaN
# 21      Ani Nahapetian       NaN
# 22      Ani Nahapetian       NaN
# 23      Ani Nahapetian       NaN
# 24      Ani Nahapetian       NaN
# 25      Ani Nahapetian       NaN
# 26      Ani Nahapetian       NaN
# ...

# %%
uniques = np.unique(catalog_content['faculty'].tolist())

# %%
print(uniques)
# Out:
# ['Ani Nahapetian' 'Brad Jackson' 'Hamid Johari' 'Kyle Dewey'
#  'Peter L Bishay' 'Shadi Mahjoob' 'Steven Fitzgerald']
